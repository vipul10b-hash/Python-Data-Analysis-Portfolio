# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### HEADING
# # HEADING 1
# ## HEADING 2
# ### HEADING 3
# #### HEADING 4
# ##### HEADING 5
# #### HI I AM VIPUL CAN I HELP YOU?
# ### BULLETS
# - MANGO
# - BANANA
# - APPLE
#     * VIPUL
# ### HIGHLIGHT
# `VIPUL PANDEY`
# ### FORMATING
# *ITALIC*
# **BOLD**
# ***BOLD+ITALIC***

# %%
# int a=10
a=10
type(a)
# Out:
# int

# %% [markdown]
# # Topics
# - variale
# - data types
# - operators
# - except sequence
# - print statement
#   # variable
#   Variables are used to store values.They act as place holders for various types of data such as list,numbers,strings or objects.
#   # rules for assigning a variables :
#   - Variable names must start with a letter or underscore(_),folloewd by letters,numbers,or underscores.
#   - Variables names are case senstive
#   - No special characters ( except underscore) are allowed in variables names
#   - keyword cannot be used for assigning a variables like if-else , elis,while,def etc.

# %%
10+10
10*20
# Out:
# 200

# %%
a=254556545655465

# %%
a
# Out:
# 254556545655465

# %%
# 1st rule
a9 = 10
a9
# Out:
# 10

# %%
9a=10
# Out:
#   Cell In[6], line 1
#     9a=10
#     ^
# SyntaxError: invalid decimal literal

# %%
# exception

_a=10

# %%
# 2nd rule
vipul=1
vipul
# Out:
# 1

# %%
# 3RD RULE
vipul_pandey=1
vipul_pandey
# Out:
# 1

# %%
vipul pandey
# Out:
#   Cell In[12], line 1
#     vipul pandey
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Data types
# - int
# - float
# - str
# - bool

# %%
# int--> whole numbers
# discrete variables
a=10
type(a)
# Out:
# int

# %%
age=21
type(age)
# Out:
# int

# %%
# float --> decimal
# continous
a=1.2
a=1.0
type(a)
# Out:
# float

# %%
height=175.5
type(height)
# Out:
# float

# %%
# str : sequence of characters
# 'sentance'
#"sentance"
# '''Paragraph'''
name = 'vipul'

# %%
name='vipul'
name
# Out:
# 'vipul'

# %%
sent1='Hi this side gaurav.I am a youtuber.'
sent1
# Out:
# 'Hi this side gaurav.I am a youtuber.'

# %%
sent2="Gaurav doesn't like to study"

# %%
para='''1. Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.

It is used for:

web development (server-side),
software development,
mathematics,
system scripting.
What can Python do?
Python can be used on a server to create web applications.
Python can be used alongside software to create workflows.
Python can connect to database systems. It can also read and modify files.
Python can be used to handle big data and perform complex mathematics.
Python can be used for rapid prototyping, or for production-ready software development.'''
print(para)
# Out:
# 1. Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.
#
# It is used for:
#
# web development (server-side),
# software development,
# mathematics,
# system scripting.
# What can Python do?
# Python can be used on a server to create web applications.
# Python can be used alongside software to create workflows.
# Python can connect to database systems. It can also read and modify files.
# Python can be used to handle big data and perform complex mathematics.
# Python can be used for rapid prototyping, or for production-ready software development.

# %%
# bool
a = True
b = False
type(a)
# Out:
# bool

# %%
# operators

# arthematics operations 
+
-
*
/
// : floor
% : modulus
** : power

# %%
a = 10
b = 20
a+b
# Out:
# 30

# %%
# modulus --> remainder

5%2
45%7
# Out:
# 3

# %%
# floor division
5//2
# Out:
# 2

# %%
# power
2*2*2
2**10
# Out:
# 1024

# %%
# round
# built in function
round(2.9)
# Out:
# 3

# %%
# assignment operators
= : assign
+= : addition and assign
-=: minus and assign
*=: multiply and assign
/= : divide and assign

# %%
a=10
a
# Out:
# 10

# %%
a+10 # operations
# Out:
# 20

# %%
a
# Out:
# 10

# %%
a=a+10 # overwrite
a
# Out:
# 60

# %%
# a=a+10
a+=10 # addition and assign
a
# Out:
# 70

# %%
# comparision operators 
> : greater than
< : less than
>= : greater than equals to
<= : less than equals to
== : equals to
|= : not equals to

# %%
10>5
10<5
# Out:
# False

# %%
10>10
# Out:
# False

# %%
10>=10
# Out:
# True

# %%
10==10
# Out:
# True

# %%
a = 10 # assign
a== 10 # compare
# Out:
# True

# %%
a==20
# Out:
# False

# %%
a!=10
# Out:
# False

# %%
# in operators
'g' in 'gaurav'
# Out:
# True

# %%
'z' in 'gaurav'
# Out:
# False

# %%
'Khushboo' in 'Khushboo likes to study math'
# Out:
# True

# %%
'varsha' in 'Khushboo likes to study math'
# Out:
# False

# %%
# logical; operatiors
and ( dot product (.))
or ( addition(+))
not

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
not True
# Out:
# False

# %%
height=168.5
type(height)
# Out:
# float

# %%
# escape sequence

\n : new line               (\=Back slash,/=Forward slash)
\t : tab space
\' : backslash single quotes
\" : backslash double quotes
\\  : double backslash

# %%
# \n
# new line

str1 = 'hi this side vipul'
str2="I am vipul"

# %%
print(str1)
# Out:
# hi this side vipul

# %%
print('hello\nworld\nvipul')
# Out:
# hello
# world
# vipul

# %%
print('hello \n world \n vipul')
# Out:
# hello
#  world
#  vipul

# %%
print('''hello
world''')
a= '''hello
world'''
a
# Out:
# hello
# world
# 'hello\nworld'

# %%
a='hi my name is vipul \n I am from delhi.'

# %%
a
# Out:
# 'hi my name is vipul \n I am from delhi.'

# %%
print(a)
# Out:
# hi my name is vipul
#  I am from delhi.

# %%
# print statements
# print--> build in functions python
# 1. advised to use print statements--> debugging , new applications,xyz
#2. forcefully print content
print(a)
# Out:
# hi my name is vipul
#  I am from delhi.

# %%
x=10
y=20
x
y
# Out:
# 20

# %%
x=10
y=20
print(x)
print(y)
# Out:
# 10
# 20

# %%
# tabspace

print('vipul\tpandey')
# Out:
# vipul	pandey

# %%
print('name\tvipul')
print('class\t3rd year')
print('subject\tmetric spaces')
print('rollno\t23/1569')
# Out:
# name	vipul
# class	3rd year
# subject	metric spaces
# rollno	23/1569

# %%
# \'
# \"

'shariq does\'t likes to study'
# Out:
# "shariq does't likes to study"

# %%
"Gaurav said, \"Anshum sir is the best teacher is skill circle\"."
# Out:
# 'Gaurav said, "Anshum sir is the best teacher is skill circle".'

# %%
print('Gaurav said,"Anshum sir is the best teacher of skillcircle".Gaurav does\'t like Trump.')
# Out:
# Gaurav said,"Anshum sir is the best teacher of skillcircle".Gaurav does't like Trump.

# %%
# \\

print('this is backslash \\')
# Out:
# this is backslash \
