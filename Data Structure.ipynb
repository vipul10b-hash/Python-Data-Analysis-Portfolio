# %% [markdown]
# # There are two types of Data Structures
#
# **1. Mutable**
# Mutable is when something is changeable or have the ability to change , in python , 'mutable' is the ability to change values . These are often objects that stores a collections of data . For example:
# - list[]
# - sets{}
# - Dictionaries {key:values}
#
# **2. Imutable**
# It is not possible to alter the  values of an object in python , it is known as imutable object.Once imutable object is created it's value remains permanent and unchangeable.
#
# - numerical(int,float)
# - strings
# - tuples

# %%
#imutable --> cannot modify --> int,float,string,bool,tuples
# mutable--> modify --> list,sets,dictionaries

# %%
a=10 #int
# built in function --> id
print(a)
id(a)
# Out:
# 10
# 140736464205000

# %%
a='gaurav'
print(a)
id(a)
# Out:
# gaurav
# 1739992098752

# %%
print(a.upper())
id(a.upper())
# Out:
# GAURAV
# 1739970570272

# %%
# list

a1=['tiger','cat','lion','pikachu','panda']
print(a1)
id(a1)
# Out:
# ['tiger', 'cat', 'lion', 'pikachu', 'panda']
# 1739992413312

# %%
a1.append('dog')
print(a1)
id(a1)
# Out:
# ['tiger', 'cat', 'lion', 'pikachu', 'panda', 'dog']
# 1739992413312

# %%
a1.insert(0,'horse') # 0 means first position and 1 is second then else other number _,_,....
print(a1)
id(a1)
# Out:
# ['horse', 'horse', 'tiger', 'cat', 'lion', 'pikachu', 'panda', 'dog']
# 1739992413312

# %%
a1.insert(3,'monkey') 
print(a1)
id(a1)
# Out:
# ['horse', 'horse', 'tiger', 'monkey', 'monkey', 'cat', 'lion', 'pikachu', 'panda', 'dog', 'monkey']
# 1739992413312

# %% [markdown]
# # string
# - entrapped 'sentance',"" or ''' ''' (paragraph)
# - duplicacy is allowed
# -  ordered
#   - immutable

# %%
# duplicacy allowed

a='aaaaa'
print(a)
# Out:
# aaaaa

# %%
a='vipul'
a
# Out:
# 'vipul'

# %% [markdown]
# # Methods
# - upper()
# - lower()
# - swapcase()

# %%
a='vipul'
a.upper()
# Out:
# 'VIPUL'

# %%
a=a.upper() # permanent
print(a)
a.lower()
# Out:
# VIPUL
# 'vipul'

# %%
'Vipul'=='vipul'
# Out:
# False

# %%
# swap case

a = ' hi THIS SIDE, vIPUL . i AM A dATA SCIENTIST . i AM FROM dELHI . aNSHUM SIR IS THE BEST TEACHER AT sKILLCIRCLE.'
print(a)
print(a.swapcase()) # change capital to small to capital word
# Out:
#  hi THIS SIDE, vIPUL . i AM A dATA SCIENTIST . i AM FROM dELHI . aNSHUM SIR IS THE BEST TEACHER AT sKILLCIRCLE.
#  HI this side, Vipul . I am a Data scientist . I am from Delhi . Anshum sir is the best teacher at Skillcircle.

# %%
# proprocessing --> nip

# strip
# lstrip
# rstrip
# split
# replace

# %%
name1 = '  Anshul bhargav '
name2 = 'Anshul bhargav'

# %%
name1==name2
# Out:
# False

# %%
# strip
# print(name1.strip())
print('|'+name1.strip()+'|')
print('|'+name1.lstrip()+'|')
print('|'+name1.rstrip()+'|')
# Out:
# |Anshul bhargav|
# |Anshul bhargav |
# |  Anshul bhargav|

# %%
str1='chicken_biryani momos lassi paratha chole_bhature egg pizza'

# %%
str1[0:15] #hetric
# Out:
# 'chicken_biryani'

# %%
a1=str1.split()
print(a1)
a1[3]
# Out:
# ['chicken_biryani', 'momos', 'lassi', 'paratha', 'chole_bhature', 'egg', 'pizza']
# 'paratha'

# %%
a1=str1.split()

# %%
str2= ' dhaniya;dal;pudina;fruits;beetroots;chawal;milk'
str2.split(';')
# Out:
# [' dhaniya', 'dal', 'pudina', 'fruits', 'beetroots', 'chawal', 'milk']

# %%
# REPLACE

name1='  Vipul Pandey '
name2= 'Vipul Pandey'

name1.strip()
# Out:
# 'Vipul Pandey'

# %%
name2='!!vi!pul!!@'
name2.strip('!@')
# Out:
# 'vi!pul'

# %%
name2.replace('!','').replace('@','')
# Out:
# 'vipul'

# %%
sent1='Anshul is an introvert'
print(sent1)
# Out:
# Anshul is an introvert

# %%
sent1.replace('Anshul','Gaurav')
# Out:
# 'Gaurav is an introvert'

# %%
# is upper
# is lower
# is alpha
# is numeric
# is alnum
# is space
# is printable
# startwith
# endwith

name='GULSHAN'
name = 'GULshan'
name.isupper()
# Out:
# False

# %%
actor='akshay'
actor.lower()
# Out:
# 'akshay'

# %%
# isalpha --> alphabetical /a-z/A-Z
actor.isalpha()
actor2='tushar kapoor'
actor2.isalpha()
# Out:
# False

# %%
# isnumeric
a='10'
# int(a)
a.isnumeric()
# Out:
# True

# %%
#isspace
val1='  '
print(val1)
val1.isspace()
# Out:
# True

# %%
# isprintable
a = 'hello\ngaurav'
a.isprintable()
# Out:
# False

# %%
sent1= 'Gaurav is a good boy'
sent1.startswith('Gaurav')
sent1.endswith('boy')
# Out:
# True

# %%
# index
# count

sent1= 'anshum likes lassi.anshum can do anything.anshum keeps on asking xyz.'
print(sent1.count('anshum'))
print(sent1.count(' '))
print(sent1.count('.'))
# Out:
# 3
# 9
# 3

# %%
name = 'Prabhakarna Sripalawardhana Attapattu Jayasuriya Laxmansriramkrishna Shivavenkata Rajasekara Srinivasana Trichipalli Ekkaparampeer Perambadur Chinnaswami Muthuswami Venugopal Iyer'

print(name)
# Out:
# Prabhakarna Sripalawardhana Attapattu Jayasuriya Laxmansriramkrishna Shivavenkata Rajasekara Srinivasana Trichipalli Ekkaparampeer Perambadur Chinnaswami Muthuswami Venugopal Iyer

# %%
# index
name.index('Rajasekara')
print(name[81:81+11])
print(name[81:92])
# Out:
#  Rajasekara
#  Rajasekara

# %% [markdown]
# # lists
#
# - mutable
# - multiple data types are allowed
# - ordered
# - duplicacy is allowed

# %%
l1=['Gaurav','anushu','varsha','Aditya']
l1
# Out:
# ['Gaurav', 'anushu', 'varsha', 'Aditya']

# %%
# typecasting
str1='abcd'
list(str1)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# ordered 
l1=['Gaurav','anshu','varsh','Aditya']
print(l1)

l1[0]
# Out:
# ['Gaurav', 'anshu', 'varsh', 'Aditya']
# 'Gaurav'

# %%
# multiple data types

l1=[1,2,3,4.3,'varsha',[1,23,34,2]]
l1
# Out:
# [1, 2, 3, 4.3, 'varsha', [1, 23, 34, 2]]

# %%
# methods
#append
l1=['anshu','anshu','gaurav','aditya','anshul']
l1
# Out:
# ['anshu', 'anshu', 'gaurav', 'aditya', 'anshul']

# %%
l1.append('varsha')
l1
# Out:
# ['anshu', 'anshu', 'gaurav', 'aditya', 'anshul', 'varsha']

# %%
# insert
l1.insert(0,'vipul')

# %%
print(l1)
# Out:
# ['vipul', 'anshu', 'anshu', 'gaurav', 'aditya', 'anshul', 'varsha']

# %%
#remove-->element name
#pop --> index

l1.remove('gaurav')
l1
# Out:
# ['vipul', 'anshu', 'anshu', 'aditya', 'anshul', 'varsha']

# %%
l1.pop(0)
# Out:
# 'vipul'

# %%
l1
# Out:
# ['anshu', 'anshu', 'aditya', 'anshul', 'varsha']

# %%
# extend
marks1=[99,98,92]
marks2=[90,91,93]
#append // wrong
marks1.extend(marks2)
print(marks1)
marks1[-1]
# Out:
# [99, 98, 92, 90, 91, 93]
# 93

# %%
# clear()
marks=[98,91,92,94,91]
print(marks)
marks.clear()
print(marks)
# Out:
# [98, 91, 92, 94, 91]
# []

# %%
# sort()
# diffrence b/w sort and sorted?
l1=[2,3,11,234,24,22,4,3234,234,32,45,354]
# sorted --> built in function
print('sorted\t',sorted(l1),'temorary change') #temporary
print('real\t',(l1))
# sort --> list method
l1.sort()
print('sort\t',(l1),'for permanent change')
l1[::-1]
# Out:
# sorted	 [2, 3, 4, 11, 22, 24, 32, 45, 234, 234, 354, 3234] temorary change
# real	 [2, 3, 11, 234, 24, 22, 4, 3234, 234, 32, 45, 354]
# sort	 [2, 3, 4, 11, 22, 24, 32, 45, 234, 234, 354, 3234] for permanent change
# [3234, 354, 234, 234, 45, 32, 24, 22, 11, 4, 3, 2]

# %%
# copy

# what is deep copy and what is shallow copy?
l1=['anshu','dog','cat','tiger']# original
l2=l1.copy()#shallow copy
l1.remove('anshu')
print('l1\t',l1)
print('l2\t',l2)
# Out:
# l1	 ['dog', 'cat', 'tiger']
# l2	 ['anshu', 'dog', 'cat', 'tiger']

# %%
#index
#count

# %%
l1.index('tiger')
l1.count('tiger')
# Out:
# 1

# %% [markdown]
# # tuples
# - immutable
# - multiple data types are allowed
# - ordered
# - duplicacy is allowed
# - but,entraped is()

# %%
t1=(1,2,3,4,5,5.56,'gaurav',4,4)
t1
# Out:
# (1, 2, 3, 4, 5, 5.56, 'gaurav', 4, 4)

# %% [markdown]
# # methods
# - index
# - count

# %%
t1.index('gaurav')
t1.count(4)
# Out:
# 3

# %% [markdown]
# # dictionaries
# - key value pairs and are entrapped in {}
# - multiple data types
# - ordered
# - duplicacy is not allowed

# %%
dict1={
    'happiness':'the state of being happy','extraordinary':'very unusual or remarkable.'
}
dict1
# Out:
# {'happiness': 'the state of being happy',
#  'extraordinary': 'very unusual or remarkable.'}

# %%
dict1
# Out:
# {'happiness': 'the state of being happy',
#  'extraordinary': 'very unusual or remarkable.'}

# %%
dict2={
    'name':'Vipul',
    'course':'Data analytics','salary':100000,'age':20
}
dict2
# Out:
# {'name': 'Vipul', 'course': 'Data analytics', 'salary': 100000, 'age': 20}

# %%
# methods
dict3={
    'teeth':30,
    'marks':90
}

# %%
print(dict3,dict2)
# Out:
# {'teeth': 30, 'marks': 90} {'name': 'Vipul', 'course': 'Data analytics', 'salary': 100000, 'age': 20}

# %%
# update 
dict2.update(dict3)

# %%
dict2
# Out:
# {'name': 'Vipul',
#  'course': 'Data analytics',
#  'salary': 100000,
#  'age': 20,
#  'teeth': 30,
#  'marks': 90}

# %%
# value change
dict2['name']='Pandey'
dict2
# Out:
# {'name': 'Pandey',
#  'course': 'Data analytics',
#  'salary': 100000,
#  'age': 20,
#  'teeth': 30,
#  'marks': 90}

# %%
# clear()--> dictionary khali ho jati hai
dict1.clear()
dict1
# Out:
# {}

# %%
# keys 
# values
# items
print(dict2.keys())
print(dict2.values())
print(dict2.items())
# Out:
# dict_keys(['name', 'course', 'salary', 'age', 'teeth', 'marks'])
# dict_values(['Pandey', 'Data analytics', 100000, 20, 30, 90])
# dict_items([('name', 'Pandey'), ('course', 'Data analytics'), ('salary', 100000), ('age', 20), ('teeth', 30), ('marks', 90)])

# %%
# get
dict2.get('name')
dict2['name']
# Out:
# 'Pandey'

# %%
# dict2['beful']
dict2.get('feef')

# %%
# setdefault
dict2.setdefault('name')
# Out:
# 'Pandey'

# %%
# unknown 
dict2.setdefault('wage')

# %%
dict2
# Out:
# {'name': 'Pandey',
#  'course': 'Data analytics',
#  'salary': 100000,
#  'age': 20,
#  'teeth': 30,
#  'marks': 90,
#  'wage': None}

# %% [markdown]
# # sets
# - enterapped{}
# - duplicacy is not allowed
# - unordered
# - mutable

# %%
# making
s1 = { 1,2,3,4,5,6}
s1
type(s1)
# Out:
# set

# %%
# unordered
s2={'gaurav','varsha','roshan','aditya','khusbhoo'}
# s2[0]
s2
# Out:
# {'aditya', 'gaurav', 'khusbhoo', 'roshan', 'varsha'}

# %%
# duplicacy is not allowed
s3={1,2,1,1,1,1,1,1}
s3
# Out:
# {1, 2}

# %%
# methods
#union
#intersection
#difference

# %%
a={1,2,3,4,5}
b={4,5,6,7,8}
# common elements 4,5
# union
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a.intersection(b)
# Out:
# {4, 5}

# %%
# difference
a.difference(b)
# Out:
# {1, 2, 3}

# %%
b-a
# Out:
# {6, 7, 8}

# %%
a-b #(difference)
# Out:
# {1, 2, 3}

# %%
print('a',a)
print('b',b)
# Out:
# a {1, 2, 3, 4, 5}
# b {4, 5, 6, 7, 8}

# %%
# update
# intersection_update
# difference_update
# union--> update
a={1,2,3,4,5}
b={4,5,6,7,8}
a.update(b)
a
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
# intersection_update
a={1,2,3,4,5}
b={4,5,6,7,8}
a.intersection_update(b)
a
# Out:
# {4, 5}

# %%
# difference update
a={1,2,3,4,5}
b={4,5,6,7,8}
a.difference_update(b)
a
# Out:
# {1, 2, 3}

# %%
a={1,2,3,4,5}
b={4,5,6,7,8}
b.difference_update(a)
b
# Out:
# {6, 7, 8}

# %%
# copy
# list--> copy
# deep copy vs shallow copy?

s1={'yashika','prince','aqram','gaurav'} # original
# deep copy
s2=s1 # duplicate set
#copy method
s2=s1.copy()# shallow 
s2.add('harsh')
print('s2',s2)
print('s1',s1)
# Out:
# s2 {'yashika', 'aqram', 'gaurav', 'harsh', 'prince'}
# s1 {'yashika', 'aqram', 'prince', 'gaurav'}

# %%
# remove
# discard
s1.remove('gaurav')
s1
# Out:
# {'aqram', 'prince', 'yashika'}

# %%
s1.discard('aqram')
s1
# Out:
# {'prince', 'yashika'}

# %%
# s1.remove('sdfdgr') #error
s1.discard('fssfr')# error free

# %%
# add 
s1.add('anshum')
s1
# Out:
# {'anshum', 'prince', 'yashika'}

# %%
# clear
s1.clear()
s1
# Out:
# set()

# %%
# empty set
s1={}
type(s1)
s2=set()
type(s2)
s2.add('yashika')
s2
# Out:
# {'yashika'}
