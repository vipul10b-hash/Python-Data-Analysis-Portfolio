# %%
import pandas as pd 
import numpy as np 

marks = pd.Series(np.random.randint(0,101,500))

# %%
marks
# Out:
# 0      23
# 1      27
# 2      55
# 3      49
# 4      50
#        ..
# 495    70
# 496    43
# 497    74
# 498    16
# 499    31
# Length: 500, dtype: int32

# %%
import seaborn as sns 
sns.histplot(marks)
# Out:
# <Axes: ylabel='Count'>

# %%
nl = []

for i in range(2):
    nl.append(marks.sample(30).mean())

nl
# Out:
# [np.float64(60.266666666666666), np.float64(49.06666666666667)]

# %%
sns.kdeplot(nl)
# Out:
# <Axes: ylabel='Density'>
