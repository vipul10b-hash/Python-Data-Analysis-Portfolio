# %% [markdown]
# # Today's Topics
# - what are functions
# - function arguments
# - local and global variables
# - return statements
# - global keyword
#
# ### What are **Functions** in Python?
#
# In **Python**, a **function** is a block of reusable code that performs a specific task. Functions help you break your program into smaller, manageable parts and avoid repeating the same code multiple times.
#
# ---
#
# ### Why Use Functions?
#
# * **Code Reusability**: Write once, use many times.
# * **Modularity**: Break down large problems into smaller parts.
# * **Readability**: Makes your code cleaner and easier to understand.
# * **Maintainability**: Easier to fix bugs or make changes.
#
# ---
#
# ### Types of Functions
#
# 1. **Built-in Functions** – e.g., `print()`, `len()`, `sum()`
# 2. **User-defined Functions** – Functions you create using `def`
#
# ---
#
# ### Points to Remember
#
# * Use `def` keyword to define a function
# * You can pass **arguments** (inputs)
# * You can use `return` to send back a result
# * Functions can have **default parameters**
# * Functions can return **multiple values** (in tuples)

# %%
l=10
b=20

print('area of deewar is',l*b)
result = l*b
# Out:
# area of deewar is 200

# %%
result
# Out:
# 200

# %%
#l=length,b=breath
# functions
# area functions

# def functions_name(parameters):
# return statements

def area(l,b): #built
    print('area of wall is',l*b)

# %%
area(10,20)
area(100,20)
area(100000,20000)
area(1065,9088)
# Out:
# area of wall is 200
# area of wall is 2000
# area of wall is 2000000000
# area of wall is 9678720

# %%
# built in functions
print('hello world')
# id('a')
# len('vipul')
sorted([13,15,4598,456,24])
# int()
# str()
# list()
#sets()
# float()
# dict()
#bool()
# Out:
# hello world
# [13, 15, 24, 456, 4598]

# %%
# abs
age=-18
abs(age)
# Out:
# 18

# %%
# min,max
# mean([13,2341,5,584,545,145])

# %%
# function arguments
#sum of 2 numbers
def sum(x,y):
    print('sum of x,y is',x+y)

# %%
sum(103,234)
# Out:
# sum of x,y is 337

# %%
# vipul(120,13)

# %%
# functions with 3- or more arguments
def mean_of_4(a,b,c,d):
    print((a+b+c+d)/4)

# %%
mean_of_4(12,23,45,63)
# Out:
# 35.75

# %%
# 1 arguement
def cube(x):
    print(x**3)
cube(3)
# Out:
# 27

# %%
# without any arguments
def greet():
    print('hello world')

# %%
# parameter--> function build
# agruments--> call function

# %%
greet()
# Out:
# hello world

# %%
# print staements vs return statements

# %%
# print statements--> degbugging
def sum(x,y):
    print(x+y)
    print('vipul')
    print('ram')

# %%
sum(10,20)
# Out:
# 30
# vipul
# ram

# %%
def sum(x,y):
    print(x+y)
    return x+y
    print('vipul')
    print('ram')

# %%
sum(10,20)
# Out:
# 30
# 30

# %%
def mean(x,y):
    print((x+y)/2)

# %%
result=mean(10,20)
# Out:
# 15.0

# %%
result

# %%
# return statement
def mean(x,y):
    return (x+y)/2

# %%
result=mean(102,24)

# %%
result
# Out:
# 63.0

# %%
x = 10 # global
def funct():
    x=20 # local
    print(x)
    return x

# %%
x
# Out:
# 10

# %%
funct()
# Out:
# 20
# 20

# %%
x
# Out:
# 10

# %%
x = 100 #global
def func1():
    y = 200 # local
    return x

# %%
func1()
# Out:
# 100

# %%
# whf
# local--> variable global
# global keyword
x = 10

def func(): # think
    global x
    x = 200

# %%
x
# Out:
# 10

# %%
# call --> done

# %%
func()

# %%
x
# Out:
# 200

# %%
# Built in function

# %%
input('enter your name')
# Out:
# enter your name vipul
# 'vipul'
